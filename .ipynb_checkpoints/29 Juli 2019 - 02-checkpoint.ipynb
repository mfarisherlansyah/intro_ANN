# %%
import numpy as np
import matplotlib.pyplot as plt

# %run -i plot_mlp_training_curves.py
# Out:
# ...
# Compare Stochastic learning strategies for MLPClassifier
# ...
#
# This example visualizes some training loss curves for different stochastic
# learning strategies, including SGD and Adam. Because of time-constraints, we
# use several small datasets, for which L-BFGS might be more suitable. The
# general trend shown in these examples seems to carry over to larger datasets,
# however.
#
# Note that those results can be highly dependent on the value of
# ``learning_rate_init``.
#
#
# learning on dataset iris
# training: constant learning-rate
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (400) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training set score: 0.980000
# Training set loss: 0.096950
# training: constant with momentum
# Training set score: 0.980000
# Training set loss: 0.049530
# ...

# %%
# %run -i plot_mlp_alpha.py

# pengaruh dari variabel alfa terhadap kerenggangan separator
# meminimalisasi error dengan kerenggangan selama proses training
# regularization namanya, nilai paling tepatnya tidak ada patokan (pake trial and error)
# berangkat dari overfitting (kelamaan di-train hasilnya malah jelek, jenuh). bisa terjadi kalo kebanyakan epoch, kelamaan
# di-train
# kadang regularization juga tidak memperkecil error. jadi pemakaiannya tergantung kondisi.
# regularization dieksplor terakhir.
# Out:
# ...
# Varying regularization in Multi-layer Perceptron
# ...
#
# A comparison of different values for regularization parameter 'alpha' on
# synthetic datasets. The plot shows that different alphas yield different
# decision functions.
#
# Alpha is a parameter for regularization term, aka penalty term, that combats
# overfitting by constraining the size of the weights. Increasing alpha may fix
# high variance (a sign of overfitting) by encouraging smaller weights, resulting
# in a decision boundary plot that appears with lesser curvatures.
# Similarly, decreasing alpha may fix high bias (a sign of underfitting) by
# encouraging larger weights, potentially resulting in a more complicated
# decision boundary.
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ...

# %%
# %run -i lvqclassification1.py

# %%
# %run -i LVQClassifier.py

# %%
# %run -i lvqclassification2_imbalance.py

# jumlah reference 30 per kelas
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\contour.py:1243: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
